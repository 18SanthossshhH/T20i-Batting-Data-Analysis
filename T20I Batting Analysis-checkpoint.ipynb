# %% [markdown]
# # T20I Batting Analysis

# %% [markdown]
# T20i WC for 2022 is gonna Begin and the cricket mood is on,Hence decided to analyze the most Entertaining part of the T20 cricket, Batting Records and i found this dataset in Kaggle which contains data for Matches held upto 2019,Let us analyze the dataset

# %%
title = 'T20i Batting Analysis'

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib 
import seaborn as sns
import warnings
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (12, 8)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# ## Data Preparation and Cleaning

# %% [markdown]
# Lets's first load our dataset and take a look on it to have an overview of what our dataset looks like and analyse it

# %%
t20_df = pd.read_csv('t20.csv')
t20_df.shape
# Out:
# (2006, 17)

# %% [markdown]
# The dataset Contains 2006 Entries and 17 columns

# %%
t20_df.head(10)
# Out:
#    Unnamed: 0                  Player       Span  Mat Inns  NO  Runs    HS  \
# 0           0         V Kohli (INDIA)  2010-2019   75   70  20  2633   94*
# 1           1       RG Sharma (INDIA)  2007-2019  104   96  14  2633   118
# 2           2         MJ Guptill (NZ)  2009-2019   83   80   7  2436   105
# 3           3  Shoaib Malik (ICC/PAK)  2006-2019  111  104  30  2263    75
# 4           4        BB McCullum (NZ)  2005-2015   71   70  10  2140   123
# 5           5         DA Warner (AUS)  2009-2019   76   76   8  2079  100*
# 6           6        EJG Morgan (ENG)  2009-2019   86   84  17  2002    91
# 7           7  Mohammad Shahzad (AFG)  2010-2018   65   65   3  1936  118*
# 8           8          JP Duminy (SA)  2007-2019   81   75  25  1934   96*
# 9           9       PR Stirling (IRE)  2009-2019   72   71   6  1929    91
#
#      Ave    BF      SR 100  50  0   4s   6s  Unnamed: 15
# 0  52.66  1907  138.07   0  24  2  247   71          NaN
# 1   32.1  1905  138.21   4  19  6  234  120          NaN
# 2  33.36  1810  134.58   2  15  2  215  113          NaN
# 3  30.58  1824  124.06   0   7  1  186   61          NaN
# 4  35.66  1571  136.21   2  13  3  199   91          NaN
# 5  30.57  1476  140.85   1  15  5  203   86          NaN
# 6  29.88  1475  135.72   0  11  3  151   96          NaN
# 7  31.22  1436  134.81   1  12  3  218   72          NaN
# 8  38.68  1532  126.24   0  11  6  138   71          NaN
# 9  29.67  1401  137.68   0  16  8  233   59          NaN

# %%
t20_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2006 entries, 0 to 2005
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   2006 non-null   int64
#  1   Player       2006 non-null   object
#  2   Span         2006 non-null   object
#  3   Mat          2006 non-null   int64
#  4   Inns         2006 non-null   object
#  5   NO           2006 non-null   object
#  6   Runs         2006 non-null   object
#  7   HS           2006 non-null   object
#  8   Ave          2006 non-null   object
#  9   BF           2006 non-null   object
#  10  SR           2006 non-null   object
#  11  100          2006 non-null   object
#  12  50           2006 non-null   object
#  13  0            2006 non-null   object
#  14  4s           2006 non-null   object
#  15  6s           2006 non-null   object
#  16  Unnamed: 15  0 non-null      float64
# dtypes: float64(1), int64(2), object(14)
# memory usage: 266.5+ KB

# %%
t20_df.nunique()
# Out:
# Unnamed: 0       50
# Player         2006
# Span            115
# Mat              87
# Inns             77
# NO               26
# Runs            453
# HS              219
# Ave             711
# BF              413
# SR             1064
# 100               6
# 50               19
# 0                12
# 4s              130
# 6s               74
# Unnamed: 15       0
# dtype: int64

# %%
t20_df.pop('Unnamed: 15')
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 2001   NaN
# 2002   NaN
# 2003   NaN
# 2004   NaN
# 2005   NaN
# Name: Unnamed: 15, Length: 2006, dtype: float64

# %%
t20_df.isnull().values.any()
# Out:
# False

# %%
t20_df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# Since the column Unamed: 15 is not needed for Analysis we have removed it using .pop() method and now we dont have any null values in the dataset

# %%
t20_df.Player.value_counts()
# Out:
# V Kohli (INDIA)        1
# S Goustis ()           1
# J Reb (Serb)           1
# AA Mulla (CAN)         1
# BJ McCarthy (IRE)      1
#                       ..
# AJ Strauss (ENG)       1
# AL Phehlukwayo (SA)    1
# AM Oyede (NGA)         1
# C Munoz-Mills (ESP)    1
# Ziaur Rahman (AFG)     1
# Name: Player, Length: 2006, dtype: int64

# %%
t20_df = t20_df.rename(columns = {'100':'Century','50':'Fifty','0':'Duck','4s':'Fours','6s':'Sixers','HS':'Highest_Score'})
t20_df
#Lets Rename the 100,50,0,4s,6s columns as Century,Fifty,Duck,Fours and Sixer columns to avoid Hassle
# Out:
#       Unnamed: 0                  Player       Span  Mat Inns  NO  Runs  \
# 0              0         V Kohli (INDIA)  2010-2019   75   70  20  2633
# 1              1       RG Sharma (INDIA)  2007-2019  104   96  14  2633
# 2              2         MJ Guptill (NZ)  2009-2019   83   80   7  2436
# 3              3  Shoaib Malik (ICC/PAK)  2006-2019  111  104  30  2263
# 4              4        BB McCullum (NZ)  2005-2015   71   70  10  2140
# ...          ...                     ...        ...  ...  ...  ..   ...
# 2001           1   SG Whittingham (SCOT)  2018-2018    3    -   -     -
# 2002           2        LJ Woodcock (NZ)  2010-2011    3    -   -     -
# 2003           3        Zamir Khan (AFG)  2012-2012    1    -   -     -
# 2004           4          S Zargar (Mex)  2019-2019    1    -   -     -
# 2005           5      Ziaur Rahman (AFG)  2019-2019    1    -   -     -
#
#      Highest_Score    Ave    BF      SR Century Fifty Duck Fours Sixers
# 0              94*  52.66  1907  138.07       0    24    2   247     71
# 1              118   32.1  1905  138.21       4    19    6   234    120
# 2              105  33.36  1810  134.58       2    15    2   215    113
# 3               75  30.58  1824  124.06       0     7    1   186     61
# 4              123  35.66  1571  136.21       2    13    3   199     91
# ...            ...    ...   ...     ...     ...   ...  ...   ...    ...
# 2001             -      -     -       -       -     -    -     -      -
# 2002             -      -     -       -       -     -    -     -      -
# 2003             -      -     -       -       -     -    -     -      -
# 2004             -      -     -       -       -     -    -     -      -
# 2005             -      -     -       -       -     -    -     -      -
#
# [2006 rows x 16 columns]

# %%
t20_df['Runs'] =t20_df['Runs'].replace(['-','0'])
t20_df['Ave'] =t20_df['Ave'].replace(['-','0'])
t20_df['SR'] =t20_df['SR'].replace(['-','0'])
t20_df['Highest_Score'] =t20_df['Highest_Score'].replace(['-','0'])

# %%
t20_df['Fifty'] =t20_df['Fifty'].replace(['-','0'])
t20_df['Century'] =t20_df['Century'].replace(['-','0'])
t20_df['Duck'] =t20_df['Duck'].replace(['-','0'])
t20_df['Fours'] =t20_df['Fours'].replace(['-','0'])
t20_df['Sixers'] =t20_df['Sixers'].replace(['-','0'])

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Now that our dataset is good to go, we can analyze it using plots, pie charts and graphs

# %%
t20_df.sample(5)
# Out:
#       Unnamed: 0               Player       Span  Mat Inns NO Runs  \
# 1586          36    K Suttisan (THAI)  2019-2019    2    2  0    4
# 899           49    Tariq Aziz (PORT)  2019-2019    4    4  1   40
# 1304           4  JA Richardson (AUS)  2017-2019    9    3  2   13
# 1622          22     RP Singh (INDIA)  2007-2009   10    2  2    3
# 321           21  Haroon Arshad (HKG)  2019-2019   10   10  3  211
#
#      Highest_Score    Ave   BF      SR Century Fifty Duck Fours Sixers
# 1586             4   2.00    5    80.0       1     1    1     1      1
# 899             23  13.33   47    85.1       1     1    1     1      2
# 1304            7*  13.00    6  216.66       1     1    1     2      1
# 1622            2*   3.00    3   100.0       1     1    1     1      1
# 321             68  30.14  154  137.01       1     1    1    15      7

# %% [markdown]
# ## Most Matches Played by a Player

# %% [markdown]
# Lets Find Out Which players have played the Most No of Matches So far and it may change in future with more no of t20is being played

# %%
matches_df = t20_df.sort_values(['Mat'],ascending=False)
most_no_of_matches_df = matches_df.iloc[0:10]
#We Create a dataframe "most_no_of_matches_df" and Store the Top 15 players who have played the most matches in it.
most_no_of_matches_df
# Out:
#     Unnamed: 0                   Player       Span  Mat Inns  NO  Runs  \
# 3            3   Shoaib Malik (ICC/PAK)  2006-2019  111  104  30  2263
# 1            1        RG Sharma (INDIA)  2007-2019  104   96  14  2633
# 33          33  Shahid Afridi (ICC/PAK)  2006-2018   99   91  12  1416
# 19          19         MS Dhoni (INDIA)  2006-2019   98   85  42  1617
# 13          13         LRPL Taylor (NZ)  2006-2019   95   87  19  1743
# 28          28         KJ O'Brien (IRE)  2008-2019   90   83  10  1504
# 10          10    Mohammad Hafeez (PAK)  2006-2018   89   86   8  1908
# 6            6         EJG Morgan (ENG)  2009-2019   86   84  17  2002
# 14          14         Umar Akmal (PAK)  2009-2019   84   79  14  1690
# 41          41  Mushfiqur Rahim (BDESH)  2006-2019   84   76  13  1265
#
#    Highest_Score    Ave    BF      SR Century Fifty Duck Fours Sixers
# 3             75  30.58  1824  124.06       2     7    1   186     61
# 1            118   32.1  1905  138.21       4    19    6   234    120
# 33           54*  17.92   944   150.0       1     4    8   103     73
# 19            56   37.6  1282  126.13       2     2    1   116     52
# 13            63  25.63  1430  121.88       2     5    5   110     65
# 28           124   20.6  1124   133.8       1     3   10   117     69
# 10            86  24.46  1643  116.12       1    10    6   196     51
# 6             91  29.88  1475  135.72       1    11    3   151     96
# 14            94   26.0  1377  122.73       2     8   10   122     55
# 41           72*  20.07  1060  119.33       1     5    5   110     31

# %%
sns.scatterplot(x = 'Mat', y = 'Player',data =most_no_of_matches_df,hue = "Mat");

# %% [markdown]
# 8 out of 10 players in this List are retired and it shows that those who played from beginning of T20s have played the most no of matches and others have to do the catchups also with more and more T20is being played this data may change very soon

# %% [markdown]
# ## Most Hundreds Scored by the Players in T20Is

# %%
is_100_df = t20_df.sort_values(['Century'],ascending=False).head()
Most_100s = is_100_df.sort_values(['Century'],ascending=True)
Most_100s
# Out:
#     Unnamed: 0                   Player       Span  Mat Inns  NO  Runs  \
# 24          24  Shakib Al Hasan (BDESH)  2006-2019   76   76  10  1567
# 25          25             C Munro (NZ)  2012-2019   60   57   7  1546
# 26          26       KS Williamson (NZ)  2011-2019   57   55   7  1505
# 27          27         S Dhawan (INDIA)  2011-2019   58   57   3  1504
# 1            1        RG Sharma (INDIA)  2007-2019  104   96  14  2633
#
#    Highest_Score    Ave    BF      SR Century Fifty Duck Fours Sixers
# 24            84  23.74  1266  123.77       3     9    5   163     33
# 25          109*  30.92   966  160.04       3     9    5   114    100
# 26           73*  31.35  1236  121.76       3     9    2   158     26
# 27            92  27.85  1173  128.21       3     9    1   166     46
# 1            118   32.1  1905  138.21       4    19    6   234    120

# %%
plt.figure(figsize=(18,6))
plt.xticks(rotation=90)

plt.title('Most 100s By a Player in T20Is')
plt.bar(Most_100s.Player,Most_100s.Century);

# %% [markdown]
# Hence we can see that all the players in this list who scored Centuries are either Openers or Top Order Batsmen,Since they have adequate no.of balls to score 100s,    Hardluck Finishers   !!!

# %% [markdown]
# ## Most Runs in T20i History

# %%
t20_df["Runs"] = t20_df["Runs"].astype(float) #Converted Strings in Dataframe to float datatype

# %%
Most_runs = t20_df.sort_values('Runs').tail(10)
Most_runs
# Out:
#    Unnamed: 0                  Player       Span  Mat Inns  NO    Runs  \
# 9           9       PR Stirling (IRE)  2009-2019   72   71   6  1929.0
# 8           8          JP Duminy (SA)  2007-2019   81   75  25  1934.0
# 7           7  Mohammad Shahzad (AFG)  2010-2018   65   65   3  1936.0
# 6           6        EJG Morgan (ENG)  2009-2019   86   84  17  2002.0
# 5           5         DA Warner (AUS)  2009-2019   76   76   8  2079.0
# 4           4        BB McCullum (NZ)  2005-2015   71   70  10  2140.0
# 3           3  Shoaib Malik (ICC/PAK)  2006-2019  111  104  30  2263.0
# 2           2         MJ Guptill (NZ)  2009-2019   83   80   7  2436.0
# 1           1       RG Sharma (INDIA)  2007-2019  104   96  14  2633.0
# 0           0         V Kohli (INDIA)  2010-2019   75   70  20  2633.0
#
#   Highest_Score    Ave    BF      SR Century Fifty Duck Fours Sixers
# 9            91  29.67  1401  137.68       1    16    8   233     59
# 8           96*  38.68  1532  126.24       1    11    6   138     71
# 7          118*  31.22  1436  134.81       1    12    3   218     72
# 6            91  29.88  1475  135.72       1    11    3   151     96
# 5          100*  30.57  1476  140.85       1    15    5   203     86
# 4           123  35.66  1571  136.21       2    13    3   199     91
# 3            75  30.58  1824  124.06       2     7    1   186     61
# 2           105  33.36  1810  134.58       2    15    2   215    113
# 1           118   32.1  1905  138.21       4    19    6   234    120
# 0           94*  52.66  1907  138.07       0    24    2   247     71

# %%
plt.scatter(Most_runs.Player,Most_runs.Runs,color='g');
plt.plot(Most_runs.Player,Most_runs.Runs,color='r',ls = '--');
plt.xticks(rotation=80)
plt.xlabel('Players')
plt.ylabel('Runs')
plt.title('Most Runs in T20I History',fontsize=20)
plt.legend(['Runs Scored']);
plt.show()

# %% [markdown]
# Virat Kholi tops the list along with Rohit sharma followed by Veterans of the Game ,But we can see that Virat have taken fewer innings than Rohit and also scored at the same Rate

# %% [markdown]
# ## Best Batting Index

# %% [markdown]
# Batting Index is a Combination of Average + Strike Rate and is used to calculate the destruction level of a batsman,It was followed few years back in Natwest T20 Blast in England,Usually a Index above 170 is considered great,Lets analyse the Batting Index for the Players

# %%
t20_df["Ave"] = t20_df["Ave"].astype(float) #Converted Strings in Dataframe to float datatype
t20_df["SR"] = t20_df["SR"].astype(float)

# %%
t20_df['batting_index'] = t20_df["Ave"] + t20_df["SR"]
t20_df.head(10)
# Out:
#    Unnamed: 0                  Player       Span  Mat Inns  NO    Runs  \
# 0           0         V Kohli (INDIA)  2010-2019   75   70  20  2633.0
# 1           1       RG Sharma (INDIA)  2007-2019  104   96  14  2633.0
# 2           2         MJ Guptill (NZ)  2009-2019   83   80   7  2436.0
# 3           3  Shoaib Malik (ICC/PAK)  2006-2019  111  104  30  2263.0
# 4           4        BB McCullum (NZ)  2005-2015   71   70  10  2140.0
# 5           5         DA Warner (AUS)  2009-2019   76   76   8  2079.0
# 6           6        EJG Morgan (ENG)  2009-2019   86   84  17  2002.0
# 7           7  Mohammad Shahzad (AFG)  2010-2018   65   65   3  1936.0
# 8           8          JP Duminy (SA)  2007-2019   81   75  25  1934.0
# 9           9       PR Stirling (IRE)  2009-2019   72   71   6  1929.0
#
#   Highest_Score    Ave    BF      SR Century Fifty Duck Fours Sixers  \
# 0           94*  52.66  1907  138.07       0    24    2   247     71
# 1           118  32.10  1905  138.21       4    19    6   234    120
# 2           105  33.36  1810  134.58       2    15    2   215    113
# 3            75  30.58  1824  124.06       2     7    1   186     61
# 4           123  35.66  1571  136.21       2    13    3   199     91
# 5          100*  30.57  1476  140.85       1    15    5   203     86
# 6            91  29.88  1475  135.72       1    11    3   151     96
# 7          118*  31.22  1436  134.81       1    12    3   218     72
# 8           96*  38.68  1532  126.24       1    11    6   138     71
# 9            91  29.67  1401  137.68       1    16    8   233     59
#
#    batting_index
# 0         190.73
# 1         170.31
# 2         167.94
# 3         154.64
# 4         171.87
# 5         171.42
# 6         165.60
# 7         166.03
# 8         164.92
# 9         167.35

# %%
batting_index_df = t20_df[['Player','Mat','batting_index']]
batting_index_df.nlargest(10,'batting_index')
# Out:
#                         Player  Mat  batting_index
# 1582           Qasim Zia (BAH)    3         404.00
# 776          Mirza Ahsan (Aut)    5         360.55
# 1400       Mohammad Asif (PAK)   11         309.00
# 1157         Irfan Mir (Chile)    4         290.42
# 434        Faisal Khan (Saudi)    4         283.94
# 985            KRP Silva (USA)    2         282.66
# 319   S Wickramasekara (CZK-R)    5         277.09
# 1060        RK Kleinveldt (SA)    6         275.00
# 1300  Mohammad Rafique (BDESH)    1         273.00
# 523           LA Dunbar (Serb)    2         271.74

# %% [markdown]
# We can see that players who have played very fewer games compared to others,SO lets fix this by checking players who have atleast 25 matches experience

# %%
updated_batting_index_df = t20_df[t20_df.Mat > 25]

# %%
updated_batting_index_df =updated_batting_index_df.nlargest(10,"batting_index")

# %% [markdown]
# Now we have filtered players by the criteria that they Must have played atleast 25 matches to be eligible

# %%
best_batting_index_df = updated_batting_index_df[["Player","Inns","batting_index"]]
best_batting_index_df
# Out:
#                  Player Inns  batting_index
# 23     GJ Maxwell (AUS)   54         195.02
# 12       AJ Finch (AUS)   58         194.82
# 25         C Munro (NZ)   57         190.96
# 0       V Kohli (INDIA)   70         190.73
# 51     KL Rahul (INDIA)   31         190.22
# 721     Hasan Ali (PAK)   10         186.48
# 60     HG Munsey (SCOT)   36         184.11
# 71         E Lewis (WI)   28         183.97
# 46   KP Pietersen (ENG)   36         179.44
# 34     Babar Azam (PAK)   36         177.66

# %%
sns.scatterplot(x= "Player",y ="batting_index",data =best_batting_index_df,hue = 'Player');
plt.xticks(rotation=90);
plt.title('Best Batting Index',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Best Batting Index')

# %% [markdown]
# So We can see that Glenn Maxwell and Aaron Finch have the Best Batting Index and mindyou both are Aussies,No wonder Aus lifted the T20Wc 2021 with their Brute force ,Also Hasan Ali @ no 6 is Quite Surprising considering he is a bowler who can tonk some balls!!!

# %% [markdown]
# ## Question and Answers

# %% [markdown]
# Now, let us answer some basic questions that one might want to know about this Dataset

# %% [markdown]
# ### Question : Which Player have the Most 50+ Scores?

# %%
t20_df["Century"] = t20_df["Century"].astype(float) #Converted Strings in Dataframe to float datatype
t20_df["Fifty"] = t20_df["Fifty"].astype(float)

# %%
t20_df['Most 50+ scores'] = t20_df["Fifty"] + t20_df["Century"]
t20_df.head(10)
# Out:
#    Unnamed: 0                  Player       Span  Mat Inns  NO    Runs  \
# 0           0         V Kohli (INDIA)  2010-2019   75   70  20  2633.0
# 1           1       RG Sharma (INDIA)  2007-2019  104   96  14  2633.0
# 2           2         MJ Guptill (NZ)  2009-2019   83   80   7  2436.0
# 3           3  Shoaib Malik (ICC/PAK)  2006-2019  111  104  30  2263.0
# 4           4        BB McCullum (NZ)  2005-2015   71   70  10  2140.0
# 5           5         DA Warner (AUS)  2009-2019   76   76   8  2079.0
# 6           6        EJG Morgan (ENG)  2009-2019   86   84  17  2002.0
# 7           7  Mohammad Shahzad (AFG)  2010-2018   65   65   3  1936.0
# 8           8          JP Duminy (SA)  2007-2019   81   75  25  1934.0
# 9           9       PR Stirling (IRE)  2009-2019   72   71   6  1929.0
#
#   Highest_Score    Ave    BF      SR  Century  Fifty Duck Fours Sixers  \
# 0           94*  52.66  1907  138.07      0.0   24.0    2   247     71
# 1           118  32.10  1905  138.21      4.0   19.0    6   234    120
# 2           105  33.36  1810  134.58      2.0   15.0    2   215    113
# 3            75  30.58  1824  124.06      2.0    7.0    1   186     61
# 4           123  35.66  1571  136.21      2.0   13.0    3   199     91
# 5          100*  30.57  1476  140.85      1.0   15.0    5   203     86
# 6            91  29.88  1475  135.72      1.0   11.0    3   151     96
# 7          118*  31.22  1436  134.81      1.0   12.0    3   218     72
# 8           96*  38.68  1532  126.24      1.0   11.0    6   138     71
# 9            91  29.67  1401  137.68      1.0   16.0    8   233     59
#
#    batting_index  Most 50+ scores
# 0         190.73             24.0
# 1         170.31             23.0
# 2         167.94             17.0
# 3         154.64              9.0
# 4         171.87             15.0
# 5         171.42             16.0
# 6         165.60             12.0
# 7         166.03             13.0
# 8         164.92             12.0
# 9         167.35             17.0

# %%
Most_50plus_scores_df = t20_df[['Player','Most 50+ scores']]
Most_50plus_scores_df = Most_50plus_scores_df.head(10)

# %%
sns.scatterplot(x = 'Player', y = 'Most 50+ scores',data =Most_50plus_scores_df,hue = "Player");
plt.xticks(rotation=90);
plt.title('Most 50+ scores',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Most 50+ scores')

# %% [markdown]
# So we can conclude that eventhough Virat doesnt have a 100 he tops the chart with 24 Fifties ,Closely followed by Rohit (19 fifties and 4 hundreds)

# %% [markdown]
# ### Question: Who scored the Most Boundaries and Sixers?

# %%
t20_df["Fours"] = t20_df["Fours"].astype(float) #Converted Strings in Dataframe to float datatype
t20_df["Sixers"] = t20_df["Sixers"].astype(float)

# %%
t20_df['Maximum_boundaries'] = t20_df["Fours"] + t20_df["Sixers"]
t20_df.head(5)
# Out:
#    Unnamed: 0                  Player       Span  Mat Inns  NO    Runs  \
# 0           0         V Kohli (INDIA)  2010-2019   75   70  20  2633.0
# 1           1       RG Sharma (INDIA)  2007-2019  104   96  14  2633.0
# 2           2         MJ Guptill (NZ)  2009-2019   83   80   7  2436.0
# 3           3  Shoaib Malik (ICC/PAK)  2006-2019  111  104  30  2263.0
# 4           4        BB McCullum (NZ)  2005-2015   71   70  10  2140.0
#
#   Highest_Score    Ave    BF      SR  Century  Fifty Duck  Fours  Sixers  \
# 0           94*  52.66  1907  138.07      0.0   24.0    2  247.0    71.0
# 1           118  32.10  1905  138.21      4.0   19.0    6  234.0   120.0
# 2           105  33.36  1810  134.58      2.0   15.0    2  215.0   113.0
# 3            75  30.58  1824  124.06      2.0    7.0    1  186.0    61.0
# 4           123  35.66  1571  136.21      2.0   13.0    3  199.0    91.0
#
#    batting_index  Most 50+ scores  Maximum_boundaries
# 0         190.73             24.0               318.0
# 1         170.31             23.0               354.0
# 2         167.94             17.0               328.0
# 3         154.64              9.0               247.0
# 4         171.87             15.0               290.0

# %%
Maximum_boundaries_df = t20_df[['Player','Maximum_boundaries']]
Maximum_boundaries_df = Maximum_boundaries_df.head(10)

# %%
plt.bar(Maximum_boundaries_df.Player,Maximum_boundaries_df.Maximum_boundaries)
plt.xticks(rotation = 85);
plt.title("Most Boundaries Scored by a Player")
# Out:
# Text(0.5, 1.0, 'Most Boundaries Scored by a Player')

# %% [markdown]
# Rohit sharma have scored the Most boundaries with 354 (234 fours and 120 sixers) followed by M Guptill and Virat

# %% [markdown]
# ## Inferences and Conclusion:

# %% [markdown]
# Now we can understand why T20s are the crowd-pullers,They are packed with power and entertainment which is evident with the Boundaries and Strike rate of players,With T20 leagues emerging all over the world and most of the Audience shifting their focus towards T20s ,Cricket Economy is gonna circulate around this format.Virat and Rohit have dominated the Runs,50+ scores and Boundaries chart while Maxwell and Finch are Explosive batters as per data,So Box office is gauranteed when they Bat,Thank You

# %% [markdown]
# ## References:

# %% [markdown]
# Kaggle Dataset - (https://www.kaggle.com/datasets/mahendran1/icc-cricket)
# Article about T20 Economy -(https://www.businesslive.co.za/fm/life/sport/2022-08-18-big-t20-money-threatens-cricket-as-we-know-it/)
